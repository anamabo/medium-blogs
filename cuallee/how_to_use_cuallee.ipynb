# %%
# !pip install cuallee
# !pip install duckdb
# Out:
# Requirement already satisfied: cuallee in /usr/local/lib/python3.12/dist-packages (0.15.4)
# Requirement already satisfied: toolz>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from cuallee) (0.12.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.12/dist-packages (from cuallee) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->cuallee) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->cuallee) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->cuallee) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.28->cuallee) (2025.11.12)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (1.3.2)

# %% [markdown]
# # Experiments with Cuallee
# ## 1. Example using Pandas

# %%
import pandas as pd
import numpy as np
data = {
    "transaction_id": [101, 102, 103, np.nan, 105, 102],
    "store_location": ["Paris", "London", "Berlin", "Paris", "Unknown", "Bogota"],
    "amount": [50.5, 20.0, -15.0, 100.0, 60.0, 10],
    "payment_type": ["Card", "Cash", "Card", "Crypto", "Cash", "Card"]
}
sales_data = pd.DataFrame(data)

# %%
sales_data
# Out:
#    transaction_id store_location  amount payment_type
# 0           101.0          Paris    50.5         Card
# 1           102.0         London    20.0         Cash
# 2           103.0         Berlin   -15.0         Card
# 3             NaN          Paris   100.0       Crypto
# 4           105.0        Unknown    60.0         Cash
# 5           102.0         Bogota    10.0         Card

# %%
from cuallee import Check, CheckLevel

# Define the check and chain the rules
check = Check(CheckLevel.WARNING, "Sales_Data_Validation")

results_exp1 = (
    check
    .is_complete("transaction_id")
    .is_unique("transaction_id")
    .is_positive("amount")
    .is_in("payment_type", ["Card", "Cash"])
    .is_legit("store_location")
    .validate(sales_data)
)

# %%
results_exp1
# Out:
#    id            timestamp                  check    level          column  \
# 0   1  2025-12-09 22:07:23  Sales_Data_Validation  WARNING  transaction_id
# 1   2  2025-12-09 22:07:23  Sales_Data_Validation  WARNING  transaction_id
# 2   3  2025-12-09 22:07:23  Sales_Data_Validation  WARNING          amount
# 3   4  2025-12-09 22:07:23  Sales_Data_Validation  WARNING    payment_type
# 4   5  2025-12-09 22:07:23  Sales_Data_Validation  WARNING  store_location
#
#               rule         value  rows  violations  pass_rate  pass_threshold  \
# 0      is_complete           N/A     6           1   0.833333             1.0
# 1        is_unique           N/A     6           2   0.666667             1.0
# 2  is_greater_than             0     6           1   0.833333             1.0
# 3            is_in  (Card, Cash)     6           1   0.833333             1.0
# 4         is_legit         ^\S+$     6           0   1.000000             1.0
#
#   status
# 0   FAIL
# 1   FAIL
# 2   FAIL
# 3   FAIL
# 4   PASS

# %% [markdown]
# ## 2. Example using DuckDB

# %%
import duckdb
conn = duckdb.connect(":memory:")

# Creation of the table in DuckDB
conn.sql("CREATE OR REPLACE TABLE duckdb_sales_data AS (SELECT * FROM sales_data)")

check = Check(CheckLevel.WARNING, "DuckDB", table_name="duckdb_sales_data")

results_exp2 = (
    check
    .is_complete("transaction_id")
    .is_unique("transaction_id")
    .is_positive("amount")
    .is_in("payment_type", ["Card", "Cash"])
    .is_legit("store_location")
    .validate(conn)
)

# %%
results_exp2
# Out:
#    id            timestamp   check    level          column             rule  \
# 0   1  2025-12-09 22:07:23  DuckDB  WARNING  transaction_id      is_complete
# 1   2  2025-12-09 22:07:23  DuckDB  WARNING  transaction_id        is_unique
# 2   3  2025-12-09 22:07:23  DuckDB  WARNING          amount  is_greater_than
# 3   4  2025-12-09 22:07:23  DuckDB  WARNING    payment_type            is_in
# 4   5  2025-12-09 22:07:23  DuckDB  WARNING  store_location         is_legit
#
#           value  rows  violations  pass_rate  pass_threshold status
# 0           N/A     6         1.0   0.833333             1.0   FAIL
# 1           N/A     6         2.0   0.666667             1.0   FAIL
# 2             0     6         1.0   0.833333             1.0   FAIL
# 3  (Card, Cash)     6         1.0   0.833333             1.0   FAIL
# 4         ^\S+$     6         0.0   1.000000             1.0   PASS
